# %% [markdown]
# # Task1

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import draw_phase_portrait

# %% [markdown]
# ## Unstable focus

# %%
alpha = 0.1
matrix_val = np.array([
    [alpha, alpha],
    [-1/4, 0]
])

draw_phase_portrait(matrix_val, alpha, "Unstable focus")
# Out:
# Eigenvalues of the matrix: [0.05+0.15j 0.05-0.15j]

# %% [markdown]
# ## Unstable saddle

# %%
alpha = -0.5
matrix_val = np.array([
    [alpha, alpha],
    [-1/4, 0]
])

draw_phase_portrait(matrix_val, alpha, "Unstable saddle")
# Out:
# Eigenvalues of the matrix: [-0.6830127  0.1830127]

# %% [markdown]
# ## Unstable node

# %%
alpha = 3
matrix_val = np.array([
    [alpha, alpha],
    [-1/4, 0]
])

draw_phase_portrait(matrix_val, alpha, "Unstable node")
# Out:
# Eigenvalues of the matrix: [2.72474487 0.27525513]

# %% [markdown]
# ## Stable node

# %%
alpha = -1
matrix_val = np.array([
    [alpha, -0.5*alpha],
    [-1/4, 0]
])

draw_phase_portrait(matrix_val, alpha, "stable node")
# Out:
# Eigenvalues of the matrix: [-0.85355339 -0.14644661]

# %% [markdown]
# ## Stable focus

# %%
alpha = 0.1
matrix_val = np.array([
    [-alpha, alpha],
    [-1/4, 0]
])

draw_phase_portrait(matrix_val, alpha, "stable focus")
# Out:
# Eigenvalues of the matrix: [-0.05+0.15j -0.05-0.15j]
